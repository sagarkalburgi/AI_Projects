# %%
# Image Super Resolution using Autoencoders
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from skimage.util import random_noise
import glob

# %%
# loading images 
images = glob.glob('../../GPU testings/data/lfw/**/*.jpg')

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(3, n, i+1)
  index = np.random.randint(0, len(images))
  img = image.load_img(str(images[index]), target_size=(192,192,3))
  img = image.img_to_array(img)/255.
  plt.imshow(img)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Original Image')
  ax = plt.subplot(3, n, i+1+n)
  noisy_image = random_noise(img, 's&p', amount=0.3)
  plt.imshow(noisy_image)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Noisy Image')
plt.show()

# %%
# Building a Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, UpSampling2D, add
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler

# Building the Encoder
input_img = Input(shape=(192, 192, 3))
l1 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(input_img)
l2 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l1)

l3 = MaxPooling2D(padding='same')(l2)
l3 = Dropout(0.2)(l3)
l4 = Conv2D(64, (3, 3),  padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l3)
l5 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l4)

l6 = MaxPooling2D(padding='same')(l5)
l6 = Dropout(0.2)(l6)
l7 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l6)

l8 = MaxPooling2D(padding='same')(l7)
l8 = Dropout(0.2)(l8)
l9 = Conv2D(256, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l8)

# %%
# Building the Decoder
l10 = UpSampling2D()(l9)
l10 = Dropout(0.2)(l10)
l11 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l10)

l12 = add([l7, l11])
l13 = UpSampling2D()(l12)
l13 = Dropout(0.2)(l13)
l14 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l13)
l15 = Conv2D(64, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l14)

l16 = add([l5, l14])
l17 = UpSampling2D()(l16)
l17 = Dropout(0.2)(l17)
l18 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l17)
l19 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l18)

l20 = add([l18, l2])

# %%
# chan = 3, for RGB
decoded = Conv2D(3, (3, 3), padding='same', activation='relu',
                 activity_regularizer=regularizers.l1(10e-10))(l20)

# Create our network
autoencoder = Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 192, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 96, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 96, 96, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 48, 48, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 48, 256)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 128)  295040      dropout_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 48, 48, 128)  0           conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 96, 96, 128)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 64)   73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 96, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 192, 192, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 192, 192, 64) 0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 192, 192, 32) 18464       dropout_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 192, 32) 0           conv2d_9[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 192, 192, 3)  867         add_2[0][0]
# ==================================================================================================
# Total params: 822,755
# Trainable params: 822,755
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    autoencoder,
    # to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    # show_layer_activations=False,
)

# %%
# Training the Model
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5,
                             min_lr=0.00001, mode='auto', cooldown=1)
early_stop = EarlyStopping(monitor='val_loss', patience=15)
model_checkpoint =  ModelCheckpoint('SnP_Denoising_AE.h5', save_best_only = True, monitor="val_accuracy")
callbacks = [reduce_lr, early_stop, model_checkpoint]

# %%
# Training the model
x_train_n = []
x_train_noisy = []
print('Loading Train Data.....')
progress = tqdm(total = 10000, position = 0)
for x in range(10000):
  try:
      index = np.random.randint(0, len(images))
      img = image.load_img(str(images[index]), target_size=(192,192,3))
      img = image.img_to_array(img)/255.
      x_train_n.append(img)
      x_train_noisy.append(random_noise(img, 's&p', amount=0.3))

      del images[index]
      progress.update(1)
  except:
      progress.update(1)
      print("Error loading image")
# Out:
# Loading Train Data.....
# 100%|█████████▉| 9996/10000 [01:09<00:00, 127.36it/s]

# %%
print("Length: ", len(x_train_n))
print('Training the model....')
history_ae = autoencoder.fit(np.array(x_train_noisy), np.array(x_train_n),
              epochs=100,
              batch_size=32,
              shuffle=True,
              validation_split=0.15,
              callbacks=callbacks)
# Out:
# Length:  10000
# Training the model....
# 100%|██████████| 10000/10000 [01:20<00:00, 127.36it/s]
# Epoch 1/100
# 266/266 [==============================] - 113s 287ms/step - loss: 0.0162 - accuracy: 0.6498 - val_loss: 0.0062 - val_accuracy: 0.7264
# Epoch 2/100
# d:\Users\KalburgS\Anaconda3\envs\pygames\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0049 - accuracy: 0.7384 - val_loss: 0.0052 - val_accuracy: 0.7404
# Epoch 3/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0041 - accuracy: 0.7556 - val_loss: 0.0049 - val_accuracy: 0.7404
# Epoch 4/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0037 - accuracy: 0.7707 - val_loss: 0.0043 - val_accuracy: 0.7613
# Epoch 5/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0034 - accuracy: 0.7838 - val_loss: 0.0041 - val_accuracy: 0.7744
# Epoch 6/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0030 - accuracy: 0.7929 - val_loss: 0.0034 - val_accuracy: 0.7902
# Epoch 7/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0027 - accuracy: 0.8019 - val_loss: 0.0029 - val_accuracy: 0.7997
# Epoch 8/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0024 - accuracy: 0.8110 - val_loss: 0.0027 - val_accuracy: 0.7996
# Epoch 9/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0022 - accuracy: 0.8185 - val_loss: 0.0024 - val_accuracy: 0.7975
# Epoch 10/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0021 - accuracy: 0.8226 - val_loss: 0.0023 - val_accuracy: 0.8086
# Epoch 11/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0020 - accuracy: 0.8267 - val_loss: 0.0022 - val_accuracy: 0.8145
# Epoch 12/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0019 - accuracy: 0.8299 - val_loss: 0.0020 - val_accuracy: 0.8133
# Epoch 13/100
# 266/266 [==============================] - 74s 277ms/step - loss: 0.0018 - accuracy: 0.8343 - val_loss: 0.0020 - val_accuracy: 0.8061
# Epoch 14/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0017 - accuracy: 0.8361 - val_loss: 0.0020 - val_accuracy: 0.8366
# Epoch 15/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0017 - accuracy: 0.8377 - val_loss: 0.0017 - val_accuracy: 0.8292
# Epoch 16/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0016 - accuracy: 0.8419 - val_loss: 0.0017 - val_accuracy: 0.8244
# Epoch 17/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.
100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.1548e-04 - accuracy: 0.9076 - val_loss: 5.2039e-04 - val_accuracy: 0.9008
# Epoch 87/100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.1351e-04 - accuracy: 0.9078 - val_loss: 5.0500e-04 - val_accuracy: 0.9003
# Epoch 88/100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.1141e-04 - accuracy: 0.9080 - val_loss: 5.0783e-04 - val_accuracy: 0.9016
# Epoch 89/100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.1047e-04 - accuracy: 0.9081 - val_loss: 5.0572e-04 - val_accuracy: 0.9027
# Epoch 90/100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.0945e-04 - accuracy: 0.9082 - val_loss: 5.0434e-04 - val_accuracy: 0.9018
# Epoch 91/100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.0850e-04 - accuracy: 0.9081 - val_loss: 5.0282e-04 - val_accuracy: 0.9031
# Epoch 92/100
# 266/266 [==============================] - 73s 274ms/step - loss: 4.0731e-04 - accuracy: 0.9082 - val_loss: 4.9941e-04 - val_accuracy: 0.9021
# Epoch 93/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.0622e-04 - accuracy: 0.9084 - val_loss: 5.0248e-04 - val_accuracy: 0.9025
# Epoch 94/100
# 266/266 [==============================] - 73s 276ms/step - loss: 4.0510e-04 - accuracy: 0.9085 - val_loss: 4.9887e-04 - val_accuracy: 0.9022
# Epoch 95/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.0380e-04 - accuracy: 0.9085 - val_loss: 4.9637e-04 - val_accuracy: 0.9026
# Epoch 96/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.0273e-04 - accuracy: 0.9085 - val_loss: 4.9292e-04 - val_accuracy: 0.9034
# Epoch 97/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.0162e-04 - accuracy: 0.9087 - val_loss: 4.9499e-04 - val_accuracy: 0.9026
# Epoch 98/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.0044e-04 - accuracy: 0.9087 - val_loss: 4.9321e-04 - val_accuracy: 0.9034
# Epoch 99/100
# 266/266 [==============================] - 73s 275ms/step - loss: 3.9920e-04 - accuracy: 0.9089 - val_loss: 4.9465e-04 - val_accuracy: 0.9018
# Epoch 100/100
# 266/266 [==============================] - 73s 275ms/step - loss: 3.9798e-04 - accuracy: 0.9090 - val_loss: 4.8993e-04 - val_accuracy: 0.9036

# %%
# Plotting graphs for loss
plt.plot(history_ae.history['loss'], label='training loss')
plt.plot(history_ae.history['val_loss'], label='val loss')
plt.title('Loss for AE')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Plotting graphs for accuracy
plt.plot(history_ae.history['accuracy'], label='training accuracy')
plt.plot(history_ae.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy for AE')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plotting graphs for lr
plt.plot(history_ae.history['lr'], label='learning rate')
plt.title('Learning Rate for AE')
plt.xlabel('epochs')
plt.ylabel('lr')
plt.legend()
plt.show()

# %%
x_test_n = []
x_test_noisy = []
progress = tqdm(total= len(images), position=0)
for img in images:
  img = image.load_img(img, target_size=(192,192,3))
  img = image.img_to_array(img)/255.
  x_test_n.append(img)
  x_test_noisy.append(random_noise(img, 's&p', amount=0.3))
  progress.update(1)
# Out:
# 100%|██████████| 709/709 [55:11<00:00,  4.67s/it]
# 100%|█████████▉| 708/709 [00:03<00:00, 204.16it/s]

# %%
#Evalutaing the model on test_data set
print('AE Loss and Accuracy on Test dataset....')
results_AE = autoencoder.evaluate(np.array(x_test_noisy), np.array(x_test_n))
predictions_AE = autoencoder.predict(np.array(x_test_noisy))

# Represeting Model as JSON String
autoencoder_json = autoencoder.to_json()
with open('SnP_Denoising_AE_model.json', 'w') as json_file:
  json_file.write(autoencoder_json)
# Out:
# AE Loss and Accuracy on Test dataset....
# 23/23 [==============================] - 2s 60ms/step - loss: 4.9086e-04 - accuracy: 0.9030
# d:\Users\KalburgS\Anaconda3\envs\pygames\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %%
# Building a CNN Model
input_img = Input(shape=(192, 192, 3))
l1 = Conv2D(16, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(input_img)
l2 = Conv2D(16, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l1)
l3 = Dropout(0.2)(l2)

l4 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l3)
l5 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l4)
l6 = Dropout(0.2)(l5)

l7 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l6)
l8 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l7)
l9 = Dropout(0.2)(l8)

l10 = Conv2D(3, (3, 3), padding='same', activation=None,
                 activity_regularizer=regularizers.l1(10e-10))(l9)

# Create our network
cnn = Model(input_img, l10)

cnn.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
cnn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 192, 192, 3)]     0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 192, 192, 16)      448
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 192, 192, 16)      2320
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 192, 192, 16)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 192, 192, 32)      4640
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 192, 192, 32)      9248
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 192, 192, 32)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 192, 192, 64)      18496
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 192, 192, 64)      36928
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 192, 192, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 192, 192, 3)       1731
# =================================================================
# Total params: 73,811
# Trainable params: 73,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    cnn,
    # to_file="CNN_model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    # show_layer_activations=False,
)

# %%
# Training the cnn model
model_checkpoint =  ModelCheckpoint('SnP_Denoising_CNN.h5', save_best_only = True, monitor="val_accuracy")
callbacks = [reduce_lr, early_stop, model_checkpoint]

print("Length: ", len(x_train_n))
print('Training the model....')
history_cnn = cnn.fit(np.array(x_train_noisy), np.array(x_train_n),
              epochs=100,
              batch_size=32,
              shuffle=True,
              validation_split=0.15,
              callbacks=callbacks)
# Out:
# Length:  10000
# Training the model....
# Epoch 1/100
# 266/266 [==============================] - 107s 297ms/step - loss: 0.0154 - accuracy: 0.6025 - val_loss: 0.0177 - val_accuracy: 0.7385
# Epoch 2/100
# 266/266 [==============================] - 71s 265ms/step - loss: 0.0058 - accuracy: 0.7090 - val_loss: 0.0133 - val_accuracy: 0.7578
# Epoch 3/100
# 266/266 [==============================] - 71s 266ms/step - loss: 0.0049 - accuracy: 0.7279 - val_loss: 0.0121 - val_accuracy: 0.7654
# Epoch 4/100
# 266/266 [==============================] - 71s 267ms/step - loss: 0.0043 - accuracy: 0.7388 - val_loss: 0.0089 - val_accuracy: 0.7754
# Epoch 5/100
# 266/266 [==============================] - 71s 267ms/step - loss: 0.0039 - accuracy: 0.7488 - val_loss: 0.0087 - val_accuracy: 0.7787
# Epoch 6/100
# 266/266 [==============================] - 71s 267ms/step - loss: 0.0037 - accuracy: 0.7573 - val_loss: 0.0068 - val_accuracy: 0.7893
# Epoch 7/100
# 266/266 [==============================] - 71s 267ms/step - loss: 0.0036 - accuracy: 0.7630 - val_loss: 0.0058 - val_accuracy: 0.7767
# Epoch 8/100
# 266/266 [==============================] - 71s 268ms/step - loss: 0.0033 - accuracy: 0.7704 - val_loss: 0.0057 - val_accuracy: 0.7890
# Epoch 9/100
# 266/266 [==============================] - 71s 268ms/step - loss: 0.0031 - accuracy: 0.7762 - val_loss: 0.0051 - val_accuracy: 0.8073
# Epoch 10/100
# 266/266 [==============================] - 71s 268ms/step - loss: 0.0029 - accuracy: 0.7816 - val_loss: 0.0047 - val_accuracy: 0.8110
# Epoch 11/100
# 266/266 [==============================] - 71s 268ms/step - loss: 0.0028 - accuracy: 0.7865 - val_loss: 0.0047 - val_accuracy: 0.8030
# Epoch 12/100
# 266/266 [==============================] - 71s 269ms/step - loss: 0.0026 - accuracy: 0.7901 - val_loss: 0.0037 - val_accuracy: 0.7999
# Epoch 13/100
# 266/266 [==============================] - 71s 269ms/step - loss: 0.0025 - accuracy: 0.7935 - val_loss: 0.0038 - val_accuracy: 0.7985
# Epoch 14/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0023 - accuracy: 0.7990 - val_loss: 0.0033 - val_accuracy: 0.8052
# Epoch 15/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0022 - accuracy: 0.8021 - val_loss: 0.0033 - val_accuracy: 0.8136
# Epoch 16/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0022 - accuracy: 0.8028 - val_loss: 0.0044 - val_accuracy: 0.8048
# Epoch 17/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0021 - accuracy: 0.8039 - val_loss: 0.0032 - val_accuracy: 0.8057
# Epoch 18/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0020 - accuracy: 0.8081 - val_loss: 0.0033 - val_accuracy: 0.8159
# Epoch 19/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0020 - accuracy: 0.8075 - val_loss: 0.0031 - val_accuracy: 0.8084
# Epoch 20/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0019 - accuracy: 0.8097 - val_loss: 0.0034 - val_accuracy: 0.8128
# Epoch 21/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0019 - accuracy: 0.8082 - val_loss: 0.0027 - val_accuracy: 0.8208
# Epoch 22/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0018 - accuracy: 0.8116 - val_loss: 0.0033 - val_accuracy: 0.7992
# Epoch 23/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0018 - accuracy: 0.8107 - val_loss: 0.0030 - val_accuracy: 0.8115
# Epoch 24/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0017 - accuracy: 0.8139 - val_loss: 0.0024 - val_accuracy: 0.8117
# Epoch 25/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0017 - accuracy: 0.8147 - val_loss: 0.0029 - val_accuracy: 0.8089
# Epoch 26/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0017 - accuracy: 0.8156 - val_loss: 0.0028 - val_accuracy: 0.8188
# Epoch 27/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0016 - accuracy: 0.8200 - val_loss: 0.0028 - val_accuracy: 0.8115
# Epoch 28/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0015 - accuracy: 0.8216 - val_loss: 0.0027 - val_accuracy: 0.8147
# Epoch 29/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0015 - accuracy: 0.8228 - val_loss: 0.0026 - val_accuracy: 0.8113
# Epoch 30/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0015 - accuracy: 0.8243 - val_loss: 0.0028 - val_accuracy: 0.8061
# Epoch 31/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0014 - accuracy: 0.8244 - val_loss: 0.0025 - val_accuracy: 0.8088
# Epoch 32/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0014 - accuracy: 0.8267 - val_loss: 0.0027 - val_accuracy: 0.8052
# Epoch 33/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0014 - accuracy: 0.8281 - val_loss: 0.0026 - val_accuracy: 0.8038
# Epoch 34/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0014 - accuracy: 0.8290 - val_loss: 0.0028 - val_accuracy: 0.8017
# Epoch 35/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0014 - accuracy: 0.8303 - val_loss: 0.0027 - val_accuracy: 0.7943
# Epoch 36/100
# 266/266 [==============================] - 72s 271ms/step - loss: 0.0013 - accuracy: 0.8314 - val_loss: 0.0027 - val_accuracy: 0.8029
# Epoch 37/100
# 266/266 [==============================] - 72s 271ms/step - loss: 0.0013 - accuracy: 0.8322 - val_loss: 0.0027 - val_accuracy: 0.7967
# Epoch 38/100
# 266/266 [==============================] - 72s 271ms/step - loss: 0.0013 - accuracy: 0.8327 - val_loss: 0.0028 - val_accuracy: 0.7977
# Epoch 39/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0013 - accuracy: 0.8331 - val_loss: 0.0028 - val_accuracy: 0.7958

# %%
# Plotting graphs for loss
plt.plot(history_cnn.history['loss'], label='training loss')
plt.plot(history_cnn.history['val_loss'], label='val loss')
plt.title('Loss for CNN')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Plotting graphs for accuracy
plt.plot(history_cnn.history['accuracy'], label='training accuracy')
plt.plot(history_cnn.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy for CNN')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plotting graphs for lr
plt.plot(history_cnn.history['lr'], label='learning rate')
plt.title('Learning Rate for CNN')
plt.xlabel('epochs')
plt.ylabel('lr')
plt.legend()
plt.show()

# %%
#Evalutaing the model on test_data set
print('CNN Loss and Accuracy on Test dataset...')
results_CNN = cnn.evaluate(np.array(x_test_noisy), np.array(x_test_n))
predictions_CNN = cnn.predict(np.array(x_test_noisy))

# Represeting Model as JSON String
cnn_json = cnn.to_json()
with open('SnP_Denoising_CNN_model.json', 'w') as json_file:
  json_file.write(cnn_json)
# Out:
# CNN Loss and Accuracy on Test dataset...
# 23/23 [==============================] - 2s 59ms/step - loss: 0.0028 - accuracy: 0.7921

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(4, n, i+1)
  index = np.random.randint(0, len(x_test_n))
  act_img = image.array_to_img(x_test_noisy[index])
  plt.imshow(act_img, cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('SnP Noisy Image')
  ax = plt.subplot(4, n, i+1+n)
  pred_ae = image.array_to_img(predictions_AE[index])
  plt.imshow(pred_ae, cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('AE Prediction Image')
  ax = plt.subplot(4, n, i+11+n)
  pred_cnn = image.array_to_img(predictions_CNN[index])
  plt.imshow(pred_cnn, cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('CNN Prediction Image')
  ax = plt.subplot(4, n, i+21+n)
  plt.imshow(x_test_n[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Reference Image')
plt.show()
# Out:
# 100%|██████████| 709/709 [00:16<00:00, 204.16it/s]
