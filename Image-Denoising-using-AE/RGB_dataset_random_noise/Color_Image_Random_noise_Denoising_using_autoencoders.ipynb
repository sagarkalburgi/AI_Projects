# %%
# Image Super Resolution using Autoencoders
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
from skimage.util import random_noise
import glob
import random

# %%
# loading images 
images = glob.glob('../../GPU testings/data/lfw/**/*.jpg')

# %%
noise = ['s&p', 'gaussian', 'localvar', 'poisson', 'salt', 'pepper', 'speckle']

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(3, n, i+1)
  index = np.random.randint(0, len(images))
  img = image.load_img(str(images[index]), target_size=(192,192,3))
  img = image.img_to_array(img)/255.
  plt.imshow(img)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Original Image')
  ax = plt.subplot(3, n, i+1+n)
  selected_noice = random.choice(noise)
  noisy_image = random_noise(img, selected_noice)
  plt.imshow(noisy_image)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title(f'{selected_noice} noise')
plt.show()

# %%
# Building a Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, UpSampling2D, add
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler

# Building the Encoder
input_img = Input(shape=(192, 192, 3))
l1 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(input_img)
l2 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l1)

l3 = MaxPooling2D(padding='same')(l2)
l3 = Dropout(0.2)(l3)
l4 = Conv2D(64, (3, 3),  padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l3)
l5 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l4)

l6 = MaxPooling2D(padding='same')(l5)
l6 = Dropout(0.2)(l6)
l7 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l6)

l8 = MaxPooling2D(padding='same')(l7)
l8 = Dropout(0.2)(l8)
l9 = Conv2D(256, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l8)

# %%
# Building the Decoder
l10 = UpSampling2D()(l9)
l10 = Dropout(0.2)(l10)
l11 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l10)

l12 = add([l7, l11])
l13 = UpSampling2D()(l12)
l13 = Dropout(0.2)(l13)
l14 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l13)
l15 = Conv2D(64, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l14)

l16 = add([l5, l14])
l17 = UpSampling2D()(l16)
l17 = Dropout(0.2)(l17)
l18 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l17)
l19 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l18)

l20 = add([l18, l2])

# %%
# chan = 3, for RGB
decoded = Conv2D(3, (3, 3), padding='same', activation='relu',
                 activity_regularizer=regularizers.l1(10e-10))(l20)

# Create our network
autoencoder = Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 192, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 96, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 96, 96, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 48, 48, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 48, 256)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 128)  295040      dropout_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 48, 48, 128)  0           conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 96, 96, 128)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 64)   73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 96, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 192, 192, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 192, 192, 64) 0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 192, 192, 32) 18464       dropout_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 192, 32) 0           conv2d_9[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 192, 192, 3)  867         add_2[0][0]
# ==================================================================================================
# Total params: 822,755
# Trainable params: 822,755
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    autoencoder,
    # to_file="AE_model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    # show_layer_activations=False,
)

# %%
# Training the Model
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5,
                             min_lr=0.00001, mode='auto', cooldown=1)
early_stop = EarlyStopping(monitor='val_loss', patience=15)
model_checkpoint =  ModelCheckpoint('RN_Denoising_AE.h5', save_best_only = True, monitor="val_accuracy")
callbacks = [reduce_lr, early_stop, model_checkpoint]

# %%
# Training the model
x_train_n = []
x_train_noisy = []
print('Loading Train Data.....')
progress = tqdm(total = 10000, position = 0)
for x in range(10000):
  try:
      index = np.random.randint(0, len(images))
      img = image.load_img(str(images[index]), target_size=(192,192,3))
      img = image.img_to_array(img)/255.
      x_train_n.append(img)
      x_train_noisy.append(random_noise(img, random.choice(noise)))

      del images[index]
      progress.update(1)
  except:
      progress.update(1)
      print("Error loading image")
# Out:
# Loading Train Data.....
# 100%|█████████▉| 9992/10000 [01:08<00:00, 128.46it/s]

# %%
print("Length: ", len(x_train_n))
print('Training the model....')
history_ae = autoencoder.fit(np.array(x_train_noisy), np.array(x_train_n),
              epochs=100,
              batch_size=32,
              shuffle=True,
              validation_split=0.15,
              callbacks=callbacks)
# Out:
# Length:  10000
# Training the model....
# Epoch 1/100
# 100%|██████████| 10000/10000 [01:20<00:00, 128.46it/s]
# 266/266 [==============================] - 93s 290ms/step - loss: 0.0111 - accuracy: 0.7276 - val_loss: 0.0016 - val_accuracy: 0.8307
# Epoch 2/100
# d:\Users\KalburgS\Anaconda3\envs\pygames\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0014 - accuracy: 0.8329 - val_loss: 0.0013 - val_accuracy: 0.8381
# Epoch 3/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0012 - accuracy: 0.8437 - val_loss: 0.0011 - val_accuracy: 0.8561
# Epoch 4/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0010 - accuracy: 0.8552 - val_loss: 9.7616e-04 - val_accuracy: 0.8660
# Epoch 5/100
# 266/266 [==============================] - 73s 276ms/step - loss: 9.4118e-04 - accuracy: 0.8635 - val_loss: 9.0460e-04 - val_accuracy: 0.8721
# Epoch 6/100
# 266/266 [==============================] - 73s 276ms/step - loss: 8.8273e-04 - accuracy: 0.8673 - val_loss: 8.6654e-04 - val_accuracy: 0.8729
# Epoch 7/100
# 266/266 [==============================] - 74s 277ms/step - loss: 8.4199e-04 - accuracy: 0.8706 - val_loss: 8.3991e-04 - val_accuracy: 0.8698
# Epoch 8/100
# 266/266 [==============================] - 74s 277ms/step - loss: 8.0880e-04 - accuracy: 0.8733 - val_loss: 8.0024e-04 - val_accuracy: 0.8805
# Epoch 9/100
# 266/266 [==============================] - 74s 277ms/step - loss: 7.7941e-04 - accuracy: 0.8748 - val_loss: 7.6900e-04 - val_accuracy: 0.8793
# Epoch 10/100
100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9167e-04 - accuracy: 0.9125 - val_loss: 4.0486e-04 - val_accuracy: 0.9170
# Epoch 95/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9153e-04 - accuracy: 0.9125 - val_loss: 4.0504e-04 - val_accuracy: 0.9157
# Epoch 96/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9140e-04 - accuracy: 0.9125 - val_loss: 4.0306e-04 - val_accuracy: 0.9163
# Epoch 97/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9127e-04 - accuracy: 0.9125 - val_loss: 4.0431e-04 - val_accuracy: 0.9169
# Epoch 98/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9119e-04 - accuracy: 0.9127 - val_loss: 4.0417e-04 - val_accuracy: 0.9157
# Epoch 99/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9104e-04 - accuracy: 0.9126 - val_loss: 4.0370e-04 - val_accuracy: 0.9144
# Epoch 100/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.9090e-04 - accuracy: 0.9126 - val_loss: 4.0392e-04 - val_accuracy: 0.9131

# %%
# Plotting graphs for loss
plt.plot(history_ae.history['loss'], label='training loss')
plt.plot(history_ae.history['val_loss'], label='val loss')
plt.title('Loss for AE')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Plotting graphs for accuracy
plt.plot(history_ae.history['accuracy'], label='training accuracy')
plt.plot(history_ae.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy for AE')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plotting graphs for lr
plt.plot(history_ae.history['lr'], label='learning rate')
plt.title('Learning Rate for AE')
plt.xlabel('epochs')
plt.ylabel('lr')
plt.legend()
plt.show()

# %%
x_test_n = []
x_test_noisy = []
noise_list = []
progress = tqdm(total= len(images), position=0)
for img in images:
  img = image.load_img(img, target_size=(192,192,3))
  img = image.img_to_array(img)/255.
  x_test_n.append(img)
  noise_selected = random.choice(noise)
  x_test_noisy.append(random_noise(img, noise_selected))
  noise_list.append(noise_selected)
  progress.update(1)
# Out:
# 100%|██████████| 10000/10000 [2:04:57<00:00,  1.33it/s]
#  98%|█████████▊| 697/709 [00:04<00:00, 143.02it/s]

# %%
#Evalutaing the model on test_data set
print('AE Loss and Accuracy on Test dataset....')
results_AE = autoencoder.evaluate(np.array(x_test_noisy), np.array(x_test_n))
predictions_AE = autoencoder.predict(np.array(x_test_noisy))

# Represeting Model as JSON String
autoencoder_json = autoencoder.to_json()
with open('RN_Denoising_AE_model.json', 'w') as json_file:
  json_file.write(autoencoder_json)
# Out:
# AE Loss and Accuracy on Test dataset....
# 23/23 [==============================] - 2s 77ms/step - loss: 4.0302e-04 - accuracy: 0.9106

# %%
# Building a CNN Model
input_img = Input(shape=(192, 192, 3))
l1 = Conv2D(16, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(input_img)
l2 = Conv2D(16, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l1)
l3 = Dropout(0.2)(l2)

l4 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l3)
l5 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l4)
l6 = Dropout(0.2)(l5)

l7 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l6)
l8 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l7)
l9 = Dropout(0.2)(l8)

l10 = Conv2D(3, (3, 3), padding='same', activation=None,
                 activity_regularizer=regularizers.l1(10e-10))(l9)

# Create our network
cnn = Model(input_img, l10)

cnn.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
cnn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 192, 192, 3)]     0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 192, 192, 16)      448
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 192, 192, 16)      2320
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 192, 192, 16)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 192, 192, 32)      4640
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 192, 192, 32)      9248
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 192, 192, 32)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 192, 192, 64)      18496
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 192, 192, 64)      36928
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 192, 192, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 192, 192, 3)       1731
# =================================================================
# Total params: 73,811
# Trainable params: 73,811
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(
    cnn,
    # to_file="CNN_model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    # show_layer_activations=False,
)
# Out:
# 100%|██████████| 709/709 [00:20<00:00, 143.02it/s]

# %%
# Training the cnn model
model_checkpoint =  ModelCheckpoint('RN_Denoising_CNN.h5', save_best_only = True, monitor="val_accuracy")
callbacks = [reduce_lr, early_stop, model_checkpoint]

print("Length: ", len(x_train_n))
print('Training the model....')
history_cnn = cnn.fit(np.array(x_train_noisy), np.array(x_train_n),
              epochs=100,
              batch_size=32,
              shuffle=True,
              validation_split=0.15,
              callbacks=callbacks)
# Out:
# Length:  10000
# Training the model....
# Epoch 1/100
# 266/266 [==============================] - 79s 282ms/step - loss: 0.0131 - accuracy: 0.6523 - val_loss: 0.0091 - val_accuracy: 0.8092
# Epoch 2/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0033 - accuracy: 0.7647 - val_loss: 0.0099 - val_accuracy: 0.8338
# Epoch 3/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0024 - accuracy: 0.7929 - val_loss: 0.0113 - val_accuracy: 0.8413
# Epoch 4/100
# 266/266 [==============================] - 72s 271ms/step - loss: 0.0021 - accuracy: 0.8060 - val_loss: 0.0108 - val_accuracy: 0.8565
# Epoch 5/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0018 - accuracy: 0.8157 - val_loss: 0.0096 - val_accuracy: 0.8603
# Epoch 6/100
# 266/266 [==============================] - 72s 271ms/step - loss: 0.0018 - accuracy: 0.8196 - val_loss: 0.0082 - val_accuracy: 0.8639
# Epoch 7/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0016 - accuracy: 0.8262 - val_loss: 0.0089 - val_accuracy: 0.8563
# Epoch 8/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0015 - accuracy: 0.8290 - val_loss: 0.0070 - val_accuracy: 0.8512
# Epoch 9/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0015 - accuracy: 0.8307 - val_loss: 0.0080 - val_accuracy: 0.8620
# Epoch 10/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0015 - accuracy: 0.8299 - val_loss: 0.0063 - val_accuracy: 0.8612
# Epoch 11/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0013 - accuracy: 0.8345 - val_loss: 0.0081 - val_accuracy: 0.8617
# Epoch 12/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0013 - accuracy: 0.8380 - val_loss: 0.0071 - val_accuracy: 0.8628
# Epoch 13/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0012 - accuracy: 0.8398 - val_loss: 0.0073 - val_accuracy: 0.8703
# Epoch 14/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0012 - accuracy: 0.8407 - val_loss: 0.0066 - val_accuracy: 0.8711
# Epoch 15/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0012 - accuracy: 0.8417 - val_loss: 0.0071 - val_accuracy: 0.8702
# Epoch 16/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0012 - accuracy: 0.8427 - val_loss: 0.0066 - val_accuracy: 0.8755
# Epoch 17/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0012 - accuracy: 0.8435 - val_loss: 0.0064 - val_accuracy: 0.8572
# Epoch 18/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.8442 - val_loss: 0.0070 - val_accuracy: 0.8701
# Epoch 19/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.8450 - val_loss: 0.0072 - val_accuracy: 0.8721
# Epoch 20/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0011 - accuracy: 0.8448 - val_loss: 0.0063 - val_accuracy: 0.8733
# Epoch 21/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0011 - accuracy: 0.8465 - val_loss: 0.0066 - val_accuracy: 0.8643
# Epoch 22/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0011 - accuracy: 0.8478 - val_loss: 0.0071 - val_accuracy: 0.8684
# Epoch 23/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0011 - accuracy: 0.8484 - val_loss: 0.0068 - val_accuracy: 0.8754
# Epoch 24/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0011 - accuracy: 0.8488 - val_loss: 0.0071 - val_accuracy: 0.8738
# Epoch 25/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0011 - accuracy: 0.8495 - val_loss: 0.0069 - val_accuracy: 0.8688

# %%
# Plotting graphs for loss
plt.plot(history_cnn.history['loss'], label='training loss')
plt.plot(history_cnn.history['val_loss'], label='val loss')
plt.title('Loss for CNN')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Plotting graphs for accuracy
plt.plot(history_cnn.history['accuracy'], label='training accuracy')
plt.plot(history_cnn.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy for CNN')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plotting graphs for lr
plt.plot(history_cnn.history['lr'], label='learning rate')
plt.title('Learning Rate for CNN')
plt.xlabel('epochs')
plt.ylabel('lr')
plt.legend()
plt.show()

# %%
#Evalutaing the model on test_data set
print('CNN Loss and Accuracy on Test dataset...')
results_CNN = cnn.evaluate(np.array(x_test_noisy), np.array(x_test_n))
predictions_CNN = cnn.predict(np.array(x_test_noisy))

# Represeting Model as JSON String
cnn_json = cnn.to_json()
with open('RN_Denoising_CNN_model.json', 'w') as json_file:
  json_file.write(cnn_json)
# Out:
# CNN Loss and Accuracy on Test dataset...
# 23/23 [==============================] - 2s 76ms/step - loss: 0.0070 - accuracy: 0.8696

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(4, n, i+1)
  index = np.random.randint(0, len(x_test_n))
  act_img = image.array_to_img(x_test_noisy[index])
  plt.imshow(act_img, cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title(f'{noise_list[index]} noise')
  ax = plt.subplot(4, n, i+1+n)
  pred_ae = image.array_to_img(predictions_AE[index])
  plt.imshow(pred_ae, cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('AE Prediction Image')
  ax = plt.subplot(4, n, i+11+n)
  pred_cnn = image.array_to_img(predictions_CNN[index])
  plt.imshow(pred_cnn, cmap='gray')
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('CNN Prediction Image')
  ax = plt.subplot(4, n, i+21+n)
  plt.imshow(x_test_n[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Reference Image')
plt.show()
