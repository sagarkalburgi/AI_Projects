# %%
# Import packages
from skimage.transform import rescale
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
import glob

# %%
# loading images 
images = glob.glob('../GPU testings/data/lfw/**/*.jpg')

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(3, n, i+1)
  index = np.random.randint(0, len(images))
  img = image.load_img(str(images[index]), target_size=(192,192,3))
  image_resized = image.img_to_array(img)/255.
  plt.imshow(image_resized)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('192x192 Image')
  ax = plt.subplot(3, n, i+1+n)
  downsized_image = rescale(rescale(image_resized, 0.25,multichannel=True), 4.0, multichannel=True)
  plt.imshow(downsized_image)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('32x32 Image')
plt.show()
# Out:
# C:\Users\KalburgS\AppData\Local\Temp\ipykernel_15416\1751483802.py:13: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   downsized_image = rescale(rescale(image_resized, 0.25,multichannel=True), 4.0, multichannel=True)

# %%
# Building a Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, UpSampling2D, add
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler

# Building the Encoder
input_img = Input(shape=(192, 192, 3))
l1 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(input_img)
l2 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l1)

l3 = MaxPooling2D(padding='same')(l2)
l3 = Dropout(0.2)(l3)
l4 = Conv2D(64, (3, 3),  padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l3)
l5 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l4)

l6 = MaxPooling2D(padding='same')(l5)
l6 = Dropout(0.2)(l6)
l7 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l6)

l8 = MaxPooling2D(padding='same')(l7)
l8 = Dropout(0.2)(l8)
l9 = Conv2D(256, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l8)

# %%
# Building the Decoder
l10 = UpSampling2D()(l9)
l10 = Dropout(0.2)(l10)
l11 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l10)

l12 = add([l7, l11])
l13 = UpSampling2D()(l12)
l13 = Dropout(0.2)(l13)
l14 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l13)
l15 = Conv2D(64, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l14)

l16 = add([l5, l14])
l17 = UpSampling2D()(l16)
l17 = Dropout(0.2)(l17)
l18 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l17)
l19 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l18)

l20 = add([l18, l2])

# %%
# chan = 3, for RGB
decoded = Conv2D(3, (3, 3), padding='same', activation='relu',
                 activity_regularizer=regularizers.l1(10e-10))(l20)

# Create our network
autoencoder = Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 192, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 96, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 96, 96, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 48, 48, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 48, 256)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 128)  295040      dropout_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 48, 48, 128)  0           conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 96, 96, 128)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 64)   73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 96, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 192, 192, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 192, 192, 64) 0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 192, 192, 32) 18464       dropout_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 192, 32) 0           conv2d_9[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 192, 192, 3)  867         add_2[0][0]
# ==================================================================================================
# Total params: 822,755
# Trainable params: 822,755
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    autoencoder,
    # to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    # show_layer_activations=False,
)

# %%
# Defining callback functions
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=8,
                             min_lr=0.00001, mode='auto', cooldown=2)
early_stop = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint =  ModelCheckpoint('ISR_AutoEncoder.h5', save_best_only = True, monitor="val_accuracy")
callbacks = [reduce_lr, early_stop, model_checkpoint]

# %%
# Training the model
x_train_n = []
x_train_down = []
print('Loading Train Data.....')
progress = tqdm(total = 10000, position = 0)
for x in range(10000):
  try:
      index = np.random.randint(0, len(images))
      img = image.load_img(str(images[index]), target_size=(192,192,3))
      image_resized = image.img_to_array(img)/255.
      x_train_n.append(image_resized)
      x_train_down.append(rescale(rescale(image_resized, 0.25,
                                          multichannel=True),
                                  4.0, multichannel=True))
      del images[index]
      progress.update(1)
  except:
      del images[index]
      progress.update(1)
      print("Error loading image")
# Out:
# Loading Train Data.....
#   0%|          | 0/10000 [00:00<?, ?it/s]C:\Users\KalburgS\AppData\Local\Temp\ipykernel_15416\1829731230.py:12: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   x_train_down.append(rescale(rescale(image_resized, 0.25,
# 100%|█████████▉| 9996/10000 [01:38<00:00, 101.23it/s]

# %%
print("Length: ", len(x_train_n))
print('Training the model....')
history_ae = autoencoder.fit(np.array(x_train_down), np.array(x_train_n),
              epochs=100,
              batch_size=32,
              shuffle=True,
              validation_split=0.15,
              callbacks=callbacks)
# Out:
# Length:  10000
# Training the model....
# Epoch 1/100
# 100%|██████████| 10000/10000 [01:50<00:00, 101.23it/s]
# 266/266 [==============================] - 83s 282ms/step - loss: 0.0048 - accuracy: 0.8384 - val_loss: 0.0023 - val_accuracy: 0.9128
# Epoch 2/100
# d:\Users\KalburgS\Anaconda3\envs\pygames\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 266/266 [==============================] - 71s 268ms/step - loss: 0.0021 - accuracy: 0.9022 - val_loss: 0.0019 - val_accuracy: 0.9146
# Epoch 3/100
# 266/266 [==============================] - 71s 268ms/step - loss: 0.0018 - accuracy: 0.9040 - val_loss: 0.0017 - val_accuracy: 0.9091
# Epoch 4/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0017 - accuracy: 0.9090 - val_loss: 0.0016 - val_accuracy: 0.9199
# Epoch 5/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0016 - accuracy: 0.9146 - val_loss: 0.0015 - val_accuracy: 0.9203
# Epoch 6/100
# 266/266 [==============================] - 72s 269ms/step - loss: 0.0016 - accuracy: 0.9168 - val_loss: 0.0015 - val_accuracy: 0.9236
# Epoch 7/100
# 266/266 [==============================] - 72s 270ms/step - loss: 0.0015 - accuracy: 0.9197 - val_loss: 0.0014 - val_accuracy: 0.9257
# Epoch 8/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0015 - accuracy: 0.9202 - val_loss: 0.0014 - val_accuracy: 0.9248
# Epoch 9/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0015 - accuracy: 0.9232 - val_loss: 0.0014 - val_accuracy: 0.9232
# Epoch 10/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0014 - accuracy: 0.9249 - val_loss: 0.0014 - val_accuracy: 0.9241
# Epoch 11/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0014 - accuracy: 0.9260 - val_loss: 0.0014 - val_accuracy: 0.9279
# Epoch 12/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0014 - accuracy: 0.9262 - val_loss: 0.0013 - val_accuracy: 0.9242
# Epoch 13/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0014 - accuracy: 0.9258 - val_loss: 0.0014 - val_accuracy: 0.9233
# Epoch 14/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0014 - accuracy: 0.9264 - val_loss: 0.0013 - val_accuracy: 0.9355
# Epoch 15/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0014 - accuracy: 0.9259 - val_loss: 0.0016 - val_accuracy: 0.9096
# Epoch 16/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0014 - accuracy: 0.9264 - val_loss: 0.0013 - val_accuracy: 0.9345
# Epoch 17/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0013 - accuracy: 0.9283 - val_loss: 0.0013 - val_accuracy: 0.9356
# Epoch 18/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0013 - accuracy: 0.9266 - val_loss: 0.0013 - val_accuracy: 0.9359
# Epoch 19/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0013 - accuracy: 0.9281 - val_loss: 0.0013 - val_accuracy: 0.9320
# Epoch 20/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0013 - accuracy: 0.9284 - val_loss: 0.0013 - val_accuracy: 0.9229
# Epoch 21/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0013 - accuracy: 0.9273 - val_loss: 0.0013 - val_accuracy: 0.9384
# Epoch 22/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0013 - accuracy: 0.9286 - val_loss: 0.0013 - val_accuracy: 0.9275
# Epoch 23/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0013 - accuracy: 0.9289 - val_loss: 0.0012 - val_accuracy: 0.9393
# Epoch 24/100
# 266/266 [==============================] - 72s 272ms/step - loss: 0.0013 - accuracy: 0.9282 - val_loss: 0.0012 - val_accuracy: 0.9397
# Epoch 25/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0013 - accuracy: 0.9306 - val_loss: 0.0013 - val_accuracy: 0.9450
# Epoch 26/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0013 - accuracy: 0.9280 - val_loss: 0.0013 - val_accuracy: 0.9249
# Epoch 27/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0013 - accuracy: 0.9307 - val_loss: 0.0012 - val_accuracy: 0.9353
# Epoch 28/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0013 - accuracy: 0.9307 - val_loss: 0.0012 - val_accuracy: 0.9361
# Epoch 29/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0013 - accuracy: 0.9307 - val_loss: 0.0012 - val_accuracy: 0.9338
# Epoch 30/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0013 - accuracy: 0.9309 - val_loss: 0.0012 - val_accuracy: 0.9379
# Epoch 31/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0013 - accuracy: 0.9309 - val_loss: 0.0012 - val_accuracy: 0.9161
# Epoch 32/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9309 - val_loss: 0.0012 - val_accuracy: 0.9251
# Epoch 33/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9308 - val_loss: 0.0012 - val_accuracy: 0.9403
# Epoch 34/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9358 - val_loss: 0.0012 - val_accuracy: 0.9396
# Epoch 35/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9366 - val_loss: 0.0012 - val_accuracy: 0.9373
# Epoch 36/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9362 - val_loss: 0.0012 - val_accuracy: 0.9389
# Epoch 37/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9365 - val_loss: 0.0012 - val_accuracy: 0.9449
# Epoch 38/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9360 - val_loss: 0.0012 - val_accuracy: 0.9409
# Epoch 39/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9354 - val_loss: 0.0012 - val_accuracy: 0.9437
# Epoch 40/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9363 - val_loss: 0.0012 - val_accuracy: 0.9452
# Epoch 41/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9365 - val_loss: 0.0012 - val_accuracy: 0.9316
# Epoch 42/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9360 - val_loss: 0.0012 - val_accuracy: 0.9412
# Epoch 43/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9365 - val_loss: 0.0012 - val_accuracy: 0.9399
# Epoch 44/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9361 - val_loss: 0.0012 - val_accuracy: 0.9434
# Epoch 45/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9372 - val_loss: 0.0012 - val_accuracy: 0.9379
# Epoch 46/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9370 - val_loss: 0.0012 - val_accuracy: 0.9482
# Epoch 47/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9375 - val_loss: 0.0012 - val_accuracy: 0.9452
# Epoch 48/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9374 - val_loss: 0.0012 - val_accuracy: 0.9429
# Epoch 49/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9378 - val_loss: 0.0012 - val_accuracy: 0.9393
# Epoch 50/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9385 - val_loss: 0.0012 - val_accuracy: 0.9387
# Epoch 51/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9379 - val_loss: 0.0012 - val_accuracy: 0.9404
# Epoch 52/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9384 - val_loss: 0.0012 - val_accuracy: 0.9488
# Epoch 53/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0012 - accuracy: 0.9379 - val_loss: 0.0012 - val_accuracy: 0.9371
# Epoch 54/100
# 266/266 [==============================] - 74s 276ms/step - loss: 0.0012 - accuracy: 0.9382 - val_loss: 0.0012 - val_accuracy: 0.9373
# Epoch 55/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0012 - accuracy: 0.9383 - val_loss: 0.0012 - val_accuracy: 0.9365
# Epoch 56/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9383 - val_loss: 0.0011 - val_accuracy: 0.9480
# Epoch 57/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0012 - accuracy: 0.9385 - val_loss: 0.0011 - val_accuracy: 0.9328
# Epoch 58/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0012 - accuracy: 0.9385 - val_loss: 0.0011 - val_accuracy: 0.9414
# Epoch 59/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0012 - accuracy: 0.9382 - val_loss: 0.0012 - val_accuracy: 0.9495
# Epoch 60/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9381 - val_loss: 0.0011 - val_accuracy: 0.9440
# Epoch 61/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0012 - accuracy: 0.9374 - val_loss: 0.0011 - val_accuracy: 0.9394
# Epoch 62/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0012 - accuracy: 0.9381 - val_loss: 0.0011 - val_accuracy: 0.9397
# Epoch 63/100
# 266/266 [==============================] - 74s 277ms/step - loss: 0.0012 - accuracy: 0.9380 - val_loss: 0.0011 - val_accuracy: 0.9346
# Epoch 64/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0012 - accuracy: 0.9355 - val_loss: 0.0011 - val_accuracy: 0.9476
# Epoch 65/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9373 - val_loss: 0.0011 - val_accuracy: 0.9431
# Epoch 66/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9367 - val_loss: 0.0011 - val_accuracy: 0.9397
# Epoch 67/100
# 266/266 [==============================] - 72s 271ms/step - loss: 0.0011 - accuracy: 0.9374 - val_loss: 0.0011 - val_accuracy: 0.9402
# Epoch 68/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9399 - val_loss: 0.0011 - val_accuracy: 0.9497
# Epoch 69/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9393 - val_loss: 0.0011 - val_accuracy: 0.9377
# Epoch 70/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0011 - accuracy: 0.9386 - val_loss: 0.0011 - val_accuracy: 0.9434
# Epoch 71/100
# 266/266 [==============================] - 72s 273ms/step - loss: 0.0011 - accuracy: 0.9381 - val_loss: 0.0011 - val_accuracy: 0.9431
# Epoch 72/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9379 - val_loss: 0.0011 - val_accuracy: 0.9454
# Epoch 73/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9375 - val_loss: 0.0011 - val_accuracy: 0.9322
# Epoch 74/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9380 - val_loss: 0.0011 - val_accuracy: 0.9439
# Epoch 75/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9383 - val_loss: 0.0011 - val_accuracy: 0.9386
# Epoch 76/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9374 - val_loss: 0.0011 - val_accuracy: 0.9475
# Epoch 77/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9384 - val_loss: 0.0011 - val_accuracy: 0.9419
# Epoch 78/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9394 - val_loss: 0.0011 - val_accuracy: 0.9390
# Epoch 79/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9389 - val_loss: 0.0011 - val_accuracy: 0.9375
# Epoch 80/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9393 - val_loss: 0.0011 - val_accuracy: 0.9465
# Epoch 81/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9384 - val_loss: 0.0011 - val_accuracy: 0.9471
# Epoch 82/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9388 - val_loss: 0.0011 - val_accuracy: 0.9344
# Epoch 83/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9374 - val_loss: 0.0011 - val_accuracy: 0.9455
# Epoch 84/100
# 266/266 [==============================] - 73s 273ms/step - loss: 0.0011 - accuracy: 0.9386 - val_loss: 0.0011 - val_accuracy: 0.9436
# Epoch 85/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0011 - accuracy: 0.9379 - val_loss: 0.0011 - val_accuracy: 0.9465
# Epoch 86/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0011 - accuracy: 0.9385 - val_loss: 0.0011 - val_accuracy: 0.9454
# Epoch 87/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0011 - accuracy: 0.9383 - val_loss: 0.0011 - val_accuracy: 0.9380
# Epoch 88/100
# 266/266 [==============================] - 74s 277ms/step - loss: 0.0011 - accuracy: 0.9393 - val_loss: 0.0011 - val_accuracy: 0.9400
# Epoch 89/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9386 - val_loss: 0.0011 - val_accuracy: 0.9419
# Epoch 90/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0011 - accuracy: 0.9386 - val_loss: 0.0011 - val_accuracy: 0.9409
# Epoch 91/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0011 - accuracy: 0.9383 - val_loss: 0.0011 - val_accuracy: 0.9446
# Epoch 92/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9395 - val_loss: 0.0011 - val_accuracy: 0.9452
# Epoch 93/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9388 - val_loss: 0.0011 - val_accuracy: 0.9439
# Epoch 94/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0011 - accuracy: 0.9382 - val_loss: 0.0011 - val_accuracy: 0.9458
# Epoch 95/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0011 - accuracy: 0.9382 - val_loss: 0.0011 - val_accuracy: 0.9355
# Epoch 96/100
# 266/266 [==============================] - 73s 275ms/step - loss: 0.0011 - accuracy: 0.9385 - val_loss: 0.0011 - val_accuracy: 0.9375
# Epoch 97/100
# 266/266 [==============================] - 73s 276ms/step - loss: 0.0011 - accuracy: 0.9386 - val_loss: 0.0011 - val_accuracy: 0.9401
# Epoch 98/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9384 - val_loss: 0.0011 - val_accuracy: 0.9401
# Epoch 99/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9386 - val_loss: 0.0011 - val_accuracy: 0.9432
# Epoch 100/100
# 266/266 [==============================] - 73s 274ms/step - loss: 0.0011 - accuracy: 0.9389 - val_loss: 0.0011 - val_accuracy: 0.9390

# %%
# Plotting graphs for loss
plt.plot(history_ae.history['loss'], label='training loss')
plt.plot(history_ae.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Plotting graphs for Accuracy
plt.plot(history_ae.history['accuracy'], label='training accuracy')
plt.plot(history_ae.history['val_accuracy'], label='val accuracy')
plt.title('accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# Plotting graphs for lr
plt.plot(history_ae.history['lr'], label='learning rate')
plt.title('Learning Rate')
plt.xlabel('epochs')
plt.ylabel('lr')
plt.legend()
plt.show()

# %%
x_test_n = []
x_test_down = []
progress = tqdm(total= len(images), position=0)
for img in images:
  img = image.load_img(str(img), target_size=(192,192,3))
  image_resized = image.img_to_array(img)/255.
  x_test_n.append(image_resized)
  x_test_down.append(rescale(rescale(image_resized, 0.25,
                                      multichannel=True),
                              4.0, multichannel=True))
  progress.update(1)
# Out:
# 100%|██████████| 10000/10000 [2:03:20<00:00,  1.35it/s]
# C:\Users\KalburgS\AppData\Local\Temp\ipykernel_15416\4090388254.py:8: FutureWarning: `multichannel` is a deprecated argument name for `rescale`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   x_test_down.append(rescale(rescale(image_resized, 0.25,
#  99%|█████████▉| 701/709 [00:08<00:00, 94.23it/s]

# %%
print('Loss and Accuracy on test data....')
results = autoencoder.evaluate(np.array(x_test_down), np.array(x_test_n))
# Out:
# Loss and Accuracy on test data....
# 23/23 [==============================] - 2s 77ms/step - loss: 0.0010 - accuracy: 0.9389

# %%
predictions = autoencoder.predict(np.array(x_test_down))

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(3, n, i+1)
  index = np.random.randint(0, len(x_test_down))
  plt.imshow(x_test_down[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('32x32 Image')
  ax = plt.subplot(3, n, i+1+n)
  plt.imshow(predictions[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('AE Predictions')
  ax = plt.subplot(3, n, i+11+n)
  plt.imshow(predictions[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('192x192 Image')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 100%|██████████| 709/709 [00:25<00:00, 94.23it/s]

# %%
# Represeting Model as JSON String
autoencoder_json = autoencoder.to_json()
with open('ISR_model.json', 'w') as json_file:
  json_file.write(autoencoder_json)
