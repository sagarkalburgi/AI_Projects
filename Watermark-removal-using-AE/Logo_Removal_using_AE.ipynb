# %%
# Import packages
from skimage.transform import rescale
from keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import tensorflow as tf
import glob, random, string
from PIL import Image, ImageDraw, ImageFont

# %%
# loading images 
images = glob.glob('../../GPU testings/data/lfw/**/*.jpg')

# %%
def add_logo(index):
    img = Image.open(str(images[index])).convert("RGBA")
    txt = Image.new('RGBA', img.size, (255,255,255,0))
    font = ImageFont.truetype("arial.ttf", 15)
    draw = ImageDraw.Draw(txt)
    width, height = img.size 
    for i in range(random.randint(0,10)):
        x=random.randint(0, width)
        y=random.randint(0, height)
        text = ''.join(random.SystemRandom().choice(string.ascii_letters + string.digits) for _ in range(random.randint(0,10)))
        draw.text((x,y), text, fill=(255,255,255, random.randint(100, 200)), font=font)
    
    imprinted_image = Image.alpha_composite(img, txt)
    rgb_imprinted_image = imprinted_image.convert('RGB')
    return rgb_imprinted_image.resize((192, 192))

# %%
n = 7
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(3, n, i+1)
  index = np.random.randint(0, len(images))
  img = image.load_img(str(images[index]), target_size=(192,192,3))
  image_resized = image.img_to_array(img)/255.
  plt.imshow(image_resized)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Original Image')
  ax = plt.subplot(3, n, i+1+n)
  logo_image = add_logo(index)
  plt.imshow(logo_image)
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Watermarked Image')
plt.show()

# %%
# Building a Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, UpSampling2D, add
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, LearningRateScheduler

# Building the Encoder
input_img = Input(shape=(192, 192, 3))
l1 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(input_img)
l2 = Conv2D(32, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l1)

l3 = MaxPooling2D(padding='same')(l2)
l3 = Dropout(0.2)(l3)
l4 = Conv2D(64, (3, 3),  padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l3)
l5 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l4)

l6 = MaxPooling2D(padding='same')(l5)
l6 = Dropout(0.2)(l6)
l7 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l6)

l8 = MaxPooling2D(padding='same')(l7)
l8 = Dropout(0.2)(l8)
l9 = Conv2D(256, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l8)

# %%
# Building the Decoder
l10 = UpSampling2D()(l9)
l10 = Dropout(0.2)(l10)
l11 = Conv2D(128, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l10)

l12 = add([l7, l11])
l13 = UpSampling2D()(l12)
l13 = Dropout(0.2)(l13)
l14 = Conv2D(64, (3, 3), padding='same', activation='relu',
            activity_regularizer=regularizers.l1(10e-10))(l13)
l15 = Conv2D(64, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l14)

l16 = add([l5, l14])
l17 = UpSampling2D()(l16)
l17 = Dropout(0.2)(l17)
l18 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l17)
l19 = Conv2D(32, (3, 3), padding='same', activation='relu',
             activity_regularizer=regularizers.l1(10e-10))(l18)

l20 = add([l18, l2])

# %%
# chan = 3, for RGB
decoded = Conv2D(3, (3, 3), padding='same', activation='relu',
                 activity_regularizer=regularizers.l1(10e-10))(l20)

# Create our network
autoencoder = Model(input_img, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 192, 192, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 192, 192, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 192, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 96, 96, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 96, 96, 32)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 64)   18496       dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 48, 48, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 48, 48, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 48, 48, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 24, 24, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 24, 24, 128)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 24, 24, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 48, 48, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 48, 48, 256)  0           up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 48, 128)  295040      dropout_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 48, 48, 128)  0           conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 96, 96, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 96, 96, 128)  0           up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 96, 96, 64)   73792       dropout_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 96, 64)   0           conv2d_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 192, 192, 64) 0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 192, 192, 64) 0           up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 192, 192, 32) 18464       dropout_5[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 192, 192, 32) 0           conv2d_9[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 192, 192, 3)  867         add_2[0][0]
# ==================================================================================================
# Total params: 822,755
# Trainable params: 822,755
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(
    autoencoder,
    # to_file="model.png",
    show_shapes=True,
    show_dtype=False,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
    layer_range=None,
    # show_layer_activations=False,
)

# %%
# Defining callback functions
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=8,
                             min_lr=0.00001, mode='auto', cooldown=2)
early_stop = EarlyStopping(monitor='val_loss', patience=10)
model_checkpoint =  ModelCheckpoint('LR_AutoEncoder.h5', save_best_only = True, monitor="val_accuracy")
callbacks = [reduce_lr, early_stop, model_checkpoint]

# %%
# Training the model
x_train_n = []
x_train_logo = []
print('Loading Train Data.....')
progress = tqdm(total = 10000, position = 0)
for x in range(10000):
  try:
      index = np.random.randint(0, len(images))
      img = image.load_img(str(images[index]), target_size=(192,192,3))
      image_resized = image.img_to_array(img)/255.
      x_train_n.append(image_resized)
      marked_image = add_logo(index)
      marked_image_np = image.img_to_array(marked_image)/255.
      x_train_logo.append(marked_image_np)
      
      del images[index]
      progress.update(1)
  except:
      del images[index]
      progress.update(1)
      print("Error loading image")
# Out:
# Loading Train Data.....
# 100%|█████████▉| 9998/10000 [01:51<00:00, 86.03it/s]

# %%
print("Length: ", len(x_train_n))
print('Training the model....')
history_ae = autoencoder.fit(np.array(x_train_logo), np.array(x_train_n),
              epochs=100,
              batch_size=32,
              shuffle=True,
              validation_split=0.15,
              callbacks=callbacks)
# Out:
# Length:  10000
# Training the model....
# Epoch 1/100
#   5/266 [..............................] - ETA: 1:15 - loss: 0.3799 - accuracy: 0.5049
# 100%|██████████| 10000/10000 [02:10<00:00, 86.03it/s]
# 266/266 [==============================] - 93s 320ms/step - loss: 0.0118 - accuracy: 0.8134 - val_loss: 0.0011 - val_accuracy: 0.8906
# Epoch 2/100
# d:\Users\KalburgS\Anaconda3\envs\pygames\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 266/266 [==============================] - 74s 280ms/step - loss: 9.3801e-04 - accuracy: 0.8911 - val_loss: 8.6348e-04 - val_accuracy: 0.8922
# Epoch 3/100
# 266/266 [==============================] - 73s 275ms/step - loss: 8.2568e-04 - accuracy: 0.8997 - val_loss: 7.9162e-04 - val_accuracy: 0.8886
# Epoch 4/100
# 266/266 [==============================] - 74s 278ms/step - loss: 7.6197e-04 - accuracy: 0.9055 - val_loss: 7.3034e-04 - val_accuracy: 0.8973
# Epoch 5/100
# 266/266 [==============================] - 73s 275ms/step - loss: 7.1302e-04 - accuracy: 0.9092 - val_loss: 6.7380e-04 - val_accuracy: 0.9142
# Epoch 6/100
# 266/266 [==============================] - 73s 275ms/step - loss: 6.8001e-04 - accuracy: 0.9128 - val_loss: 6.5557e-04 - val_accuracy: 0.9328
# Epoch 7/100
# 266/266 [==============================] - 73s 275ms/step - loss: 6.4302e-04 - accuracy: 0.9183 - val_loss: 6.1930e-04 - val_accuracy: 0.9242
# Epoch 8/100
# 266/266 [==============================] - 73s 274ms/step - loss: 6.2184e-04 - accuracy: 0.9219 - val_loss: 6.0408e-04 - val_accuracy: 0.9385
# Epoch 9/100
# 266/266 [==============================] - 73s 275ms/step - loss: 6.0537e-04 - accuracy: 0.9295 - val_loss: 6.0448e-04 - val_accuracy: 0.9260
# Epoch 10/100
# 266/266 [==============================] - 73s 275ms/step - loss: 5.8521e-04 - accuracy: 0.9347 - val_loss: 5.5675e-04 - val_accuracy: 0.9456
# Epoch 11/100
# 266/266 [==============================] - 73s 275ms/step - loss: 5.6920e-04 - accuracy: 0.9363 - val_loss: 5.4318e-04 - val_accuracy: 0.9341
# Epoch 12/100
# 266/266 [==============================] - 73s 274ms/step - loss: 5.5361e-04 - accuracy: 0.9369 - val_loss: 5.3211e-04 - val_accuracy: 0.9375
# Epoch 13/100
# 266/266 [==============================] - 72s 272ms/step - loss: 5.4280e-04 - accuracy: 0.9349 - val_loss: 5.2116e-04 - val_accuracy: 0.9471
# Epoch 14/100
# 266/266 [==============================] - 72s 273ms/step - loss: 5.3119e-04 - accuracy: 0.9329 - val_loss: 5.0829e-04 - val_accuracy: 0.9432
# Epoch 15/100
# 266/266 [==============================] - 74s 276ms/step - loss: 5.2188e-04 - accuracy: 0.9327 - val_loss: 5.1968e-04 - val_accuracy: 0.9332
# Epoch 16/100
# 266/266 [==============================] - 74s 279ms/step - loss: 5.1750e-04 - accuracy: 0.9324 - val_loss: 4.9201e-04 - val_accuracy: 0.9228
# Epoch 17/100
# 266/266 [==============================] - 73s 275ms/step - loss: 5.0366e-04 - accuracy: 0.9347 - val_loss: 4.8630e-04 - val_accuracy: 0.9380
# Epoch 18/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.9918e-04 - accuracy: 0.9354 - val_loss: 4.7635e-04 - val_accuracy: 0.9345
# Epoch 19/100
# 266/266 [==============================] - 77s 288ms/step - loss: 4.8961e-04 - accuracy: 0.9361 - val_loss: 4.7429e-04 - val_accuracy: 0.9254
# Epoch 20/100
# 266/266 [==============================] - 74s 277ms/step - loss: 4.8521e-04 - accuracy: 0.9366 - val_loss: 4.7179e-04 - val_accuracy: 0.9347
# Epoch 21/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.8023e-04 - accuracy: 0.9365 - val_loss: 4.6668e-04 - val_accuracy: 0.9295
# Epoch 22/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.6435e-04 - accuracy: 0.9412 - val_loss: 4.5347e-04 - val_accuracy: 0.9375
# Epoch 23/100
# 266/266 [==============================] - 73s 276ms/step - loss: 4.6086e-04 - accuracy: 0.9414 - val_loss: 4.5141e-04 - val_accuracy: 0.9425
# Epoch 24/100
# 266/266 [==============================] - 72s 272ms/step - loss: 4.5706e-04 - accuracy: 0.9410 - val_loss: 4.4629e-04 - val_accuracy: 0.9472
# Epoch 25/100
# 266/266 [==============================] - 73s 276ms/step - loss: 4.5419e-04 - accuracy: 0.9421 - val_loss: 4.4306e-04 - val_accuracy: 0.9412
# Epoch 26/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.5246e-04 - accuracy: 0.9386 - val_loss: 4.3963e-04 - val_accuracy: 0.9484
# Epoch 27/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.5148e-04 - accuracy: 0.9379 - val_loss: 4.3721e-04 - val_accuracy: 0.9267
# Epoch 28/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.4457e-04 - accuracy: 0.9396 - val_loss: 4.3813e-04 - val_accuracy: 0.9314
# Epoch 29/100
# 266/266 [==============================] - 73s 275ms/step - loss: 4.4244e-04 - accuracy: 0.9397 - val_loss: 4.4373e-04 - val_accuracy: 0.9477
# Epoch 30/100
# 266/266 [==============================] - 76s 285ms/step - loss: 4.3924e-04 - accuracy: 0.9403 - val_loss: 4.2782e-04 - val_accuracy: 0.9489
# Epoch 31/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.3674e-04 - accuracy: 0.9404 - val_loss: 4.2760e-04 - val_accuracy: 0.9491
# Epoch 32/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.3436e-04 - accuracy: 0.9413 - val_loss: 4.2629e-04 - val_accuracy: 0.9519
# Epoch 33/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.3106e-04 - accuracy: 0.9410 - val_loss: 4.1915e-04 - val_accuracy: 0.9280
# Epoch 34/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.2758e-04 - accuracy: 0.9424 - val_loss: 4.2839e-04 - val_accuracy: 0.9498
# Epoch 35/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.2424e-04 - accuracy: 0.9429 - val_loss: 4.1793e-04 - val_accuracy: 0.9473
# Epoch 36/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.2274e-04 - accuracy: 0.9433 - val_loss: 4.1703e-04 - val_accuracy: 0.9295
# Epoch 37/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.2247e-04 - accuracy: 0.9432 - val_loss: 4.1075e-04 - val_accuracy: 0.9462
# Epoch 38/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.1634e-04 - accuracy: 0.9441 - val_loss: 4.0665e-04 - val_accuracy: 0.9483
# Epoch 39/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.1761e-04 - accuracy: 0.9442 - val_loss: 4.0500e-04 - val_accuracy: 0.9538
# Epoch 40/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.1504e-04 - accuracy: 0.9443 - val_loss: 4.0943e-04 - val_accuracy: 0.9469
# Epoch 41/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.1076e-04 - accuracy: 0.9452 - val_loss: 4.0088e-04 - val_accuracy: 0.9469
# Epoch 42/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.1055e-04 - accuracy: 0.9447 - val_loss: 4.1794e-04 - val_accuracy: 0.9578
# Epoch 43/100
# 266/266 [==============================] - 80s 300ms/step - loss: 4.0851e-04 - accuracy: 0.9455 - val_loss: 3.9939e-04 - val_accuracy: 0.9481
# Epoch 44/100
# 266/266 [==============================] - 80s 300ms/step - loss: 4.0440e-04 - accuracy: 0.9451 - val_loss: 3.9657e-04 - val_accuracy: 0.9569
# Epoch 45/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.0357e-04 - accuracy: 0.9448 - val_loss: 3.9456e-04 - val_accuracy: 0.9519
# Epoch 46/100
# 266/266 [==============================] - 80s 301ms/step - loss: 4.0189e-04 - accuracy: 0.9464 - val_loss: 3.9237e-04 - val_accuracy: 0.9477
# Epoch 47/100
# 266/266 [==============================] - 79s 296ms/step - loss: 4.0124e-04 - accuracy: 0.9463 - val_loss: 3.9589e-04 - val_accuracy: 0.9541
# Epoch 48/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.9904e-04 - accuracy: 0.9465 - val_loss: 3.8847e-04 - val_accuracy: 0.9504
# Epoch 49/100
# 266/266 [==============================] - 78s 295ms/step - loss: 4.0003e-04 - accuracy: 0.9466 - val_loss: 3.8757e-04 - val_accuracy: 0.9518
# Epoch 50/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.9522e-04 - accuracy: 0.9486 - val_loss: 3.9064e-04 - val_accuracy: 0.9473
# Epoch 51/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8966e-04 - accuracy: 0.9501 - val_loss: 3.8474e-04 - val_accuracy: 0.9576
# Epoch 52/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8885e-04 - accuracy: 0.9501 - val_loss: 3.8457e-04 - val_accuracy: 0.9539
# Epoch 53/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8761e-04 - accuracy: 0.9502 - val_loss: 3.8165e-04 - val_accuracy: 0.9556
# Epoch 54/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8697e-04 - accuracy: 0.9508 - val_loss: 3.8194e-04 - val_accuracy: 0.9360
# Epoch 55/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8660e-04 - accuracy: 0.9506 - val_loss: 3.8092e-04 - val_accuracy: 0.9504
# Epoch 56/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8574e-04 - accuracy: 0.9515 - val_loss: 3.7972e-04 - val_accuracy: 0.9621
# Epoch 57/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8476e-04 - accuracy: 0.9513 - val_loss: 3.8268e-04 - val_accuracy: 0.9501
# Epoch 58/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8449e-04 - accuracy: 0.9514 - val_loss: 3.7919e-04 - val_accuracy: 0.9541
# Epoch 59/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8319e-04 - accuracy: 0.9520 - val_loss: 3.8036e-04 - val_accuracy: 0.9513
# Epoch 60/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.8233e-04 - accuracy: 0.9522 - val_loss: 3.7706e-04 - val_accuracy: 0.9607
# Epoch 61/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.8149e-04 - accuracy: 0.9512 - val_loss: 3.7586e-04 - val_accuracy: 0.9604
# Epoch 62/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.8038e-04 - accuracy: 0.9528 - val_loss: 3.7477e-04 - val_accuracy: 0.9530
# Epoch 63/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7985e-04 - accuracy: 0.9527 - val_loss: 3.7715e-04 - val_accuracy: 0.9554
# Epoch 64/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7860e-04 - accuracy: 0.9528 - val_loss: 3.8491e-04 - val_accuracy: 0.9493
# Epoch 65/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7648e-04 - accuracy: 0.9527 - val_loss: 3.7234e-04 - val_accuracy: 0.9612
# Epoch 66/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7568e-04 - accuracy: 0.9534 - val_loss: 3.7017e-04 - val_accuracy: 0.9585
# Epoch 67/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7518e-04 - accuracy: 0.9534 - val_loss: 3.7005e-04 - val_accuracy: 0.9502
# Epoch 68/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7476e-04 - accuracy: 0.9531 - val_loss: 3.7009e-04 - val_accuracy: 0.9610
# Epoch 69/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7429e-04 - accuracy: 0.9531 - val_loss: 3.7011e-04 - val_accuracy: 0.9531
# Epoch 70/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7378e-04 - accuracy: 0.9537 - val_loss: 3.6870e-04 - val_accuracy: 0.9592
# Epoch 71/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7345e-04 - accuracy: 0.9536 - val_loss: 3.6915e-04 - val_accuracy: 0.9564
# Epoch 72/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7270e-04 - accuracy: 0.9536 - val_loss: 3.6908e-04 - val_accuracy: 0.9606
# Epoch 73/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.7228e-04 - accuracy: 0.9535 - val_loss: 3.6748e-04 - val_accuracy: 0.9564
# Epoch 74/100
# 266/266 [==============================] - 80s 300ms/step - loss: 3.7114e-04 - accuracy: 0.9536 - val_loss: 3.6720e-04 - val_accuracy: 0.9544
# Epoch 75/100
# 266/266 [==============================] - 79s 295ms/step - loss: 3.7077e-04 - accuracy: 0.9535 - val_loss: 3.6672e-04 - val_accuracy: 0.9539
# Epoch 76/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.7050e-04 - accuracy: 0.9537 - val_loss: 3.6598e-04 - val_accuracy: 0.9546
# Epoch 77/100
# 266/266 [==============================] - 74s 278ms/step - loss: 3.7015e-04 - accuracy: 0.9536 - val_loss: 3.6662e-04 - val_accuracy: 0.9557
# Epoch 78/100
# 266/266 [==============================] - 96s 362ms/step - loss: 3.6998e-04 - accuracy: 0.9538 - val_loss: 3.6623e-04 - val_accuracy: 0.9560
# Epoch 79/100
# 266/266 [==============================] - 81s 304ms/step - loss: 3.6944e-04 - accuracy: 0.9539 - val_loss: 3.6688e-04 - val_accuracy: 0.9538
# Epoch 80/100
# 266/266 [==============================] - 75s 283ms/step - loss: 3.6919e-04 - accuracy: 0.9539 - val_loss: 3.6504e-04 - val_accuracy: 0.9538
# Epoch 81/100
# 266/266 [==============================] - 76s 286ms/step - loss: 3.6879e-04 - accuracy: 0.9539 - val_loss: 3.6584e-04 - val_accuracy: 0.9595
# Epoch 82/100
# 266/266 [==============================] - 76s 286ms/step - loss: 3.6866e-04 - accuracy: 0.9540 - val_loss: 3.6459e-04 - val_accuracy: 0.9547
# Epoch 83/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.6796e-04 - accuracy: 0.9541 - val_loss: 3.6371e-04 - val_accuracy: 0.9545
# Epoch 84/100
# 266/266 [==============================] - 80s 302ms/step - loss: 3.6776e-04 - accuracy: 0.9540 - val_loss: 3.6364e-04 - val_accuracy: 0.9563
# Epoch 85/100
# 266/266 [==============================] - 80s 302ms/step - loss: 3.6755e-04 - accuracy: 0.9538 - val_loss: 3.6380e-04 - val_accuracy: 0.9566
# Epoch 86/100
# 266/266 [==============================] - 80s 302ms/step - loss: 3.6735e-04 - accuracy: 0.9539 - val_loss: 3.6342e-04 - val_accuracy: 0.9544
# Epoch 87/100
# 266/266 [==============================] - 80s 301ms/step - loss: 3.6736e-04 - accuracy: 0.9541 - val_loss: 3.6332e-04 - val_accuracy: 0.9548
# Epoch 88/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.6702e-04 - accuracy: 0.9542 - val_loss: 3.6310e-04 - val_accuracy: 0.9547
# Epoch 89/100
# 266/266 [==============================] - 79s 295ms/step - loss: 3.6687e-04 - accuracy: 0.9541 - val_loss: 3.6313e-04 - val_accuracy: 0.9539
# Epoch 90/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.6669e-04 - accuracy: 0.9541 - val_loss: 3.6293e-04 - val_accuracy: 0.9540
# Epoch 91/100
# 266/266 [==============================] - 80s 300ms/step - loss: 3.6649e-04 - accuracy: 0.9541 - val_loss: 3.6260e-04 - val_accuracy: 0.9545
# Epoch 92/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.6620e-04 - accuracy: 0.9539 - val_loss: 3.6265e-04 - val_accuracy: 0.9550
# Epoch 93/100
# 266/266 [==============================] - 79s 295ms/step - loss: 3.6600e-04 - accuracy: 0.9542 - val_loss: 3.6247e-04 - val_accuracy: 0.9553
# Epoch 94/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.6594e-04 - accuracy: 0.9542 - val_loss: 3.6224e-04 - val_accuracy: 0.9547
# Epoch 95/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.6585e-04 - accuracy: 0.9541 - val_loss: 3.6202e-04 - val_accuracy: 0.9541
# Epoch 96/100
# 266/266 [==============================] - 79s 296ms/step - loss: 3.6566e-04 - accuracy: 0.9543 - val_loss: 3.6210e-04 - val_accuracy: 0.9606
# Epoch 97/100
# 266/266 [==============================] - 79s 295ms/step - loss: 3.6563e-04 - accuracy: 0.9541 - val_loss: 3.6182e-04 - val_accuracy: 0.9571
# Epoch 98/100
# 266/266 [==============================] - 79s 295ms/step - loss: 3.6564e-04 - accuracy: 0.9540 - val_loss: 3.6173e-04 - val_accuracy: 0.9583
# Epoch 99/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.6540e-04 - accuracy: 0.9541 - val_loss: 3.6157e-04 - val_accuracy: 0.9545
# Epoch 100/100
# 266/266 [==============================] - 78s 295ms/step - loss: 3.6535e-04 - accuracy: 0.9543 - val_loss: 3.6192e-04 - val_accuracy: 0.9552

# %%
# Plotting graphs for loss
plt.plot(history_ae.history['loss'], label='training loss')
plt.plot(history_ae.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
# Plotting graphs for Accuracy
plt.plot(history_ae.history['accuracy'], label='training accuracy')
plt.plot(history_ae.history['val_accuracy'], label='val accuracy')
plt.title('accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# Plotting graphs for lr
plt.plot(history_ae.history['lr'], label='learning rate')
plt.title('Learning Rate')
plt.xlabel('epochs')
plt.ylabel('lr')
plt.legend()
plt.show()

# %%
x_test_n = []
x_test_logo = []
progress = tqdm(total= len(images), position=0)
for idx, img in enumerate(images):
  img = image.load_img(str(img), target_size=(192,192,3))
  image_resized = image.img_to_array(img)/255.
  x_test_n.append(image_resized)
  marked_image = add_logo(idx)
  marked_image_np = image.img_to_array(marked_image)/255.
  x_test_logo.append(marked_image_np)
  progress.update(1)
# Out:
# 100%|██████████| 3233/3233 [01:46<00:00, 30.32it/s]
# 100%|█████████▉| 3231/3233 [00:37<00:00, 91.55it/s]

# %%
print('Loss and Accuracy on test data....')
results = autoencoder.evaluate(np.array(x_test_logo), np.array(x_test_n))
# Out:
# Loss and Accuracy on test data....
#  97/102 [===========================>..] - ETA: 0s - loss: 3.6005e-04 - accuracy: 0.9537
# 100%|██████████| 3233/3233 [00:50<00:00, 91.55it/s]
# 102/102 [==============================] - 7s 65ms/step - loss: 3.6009e-04 - accuracy: 0.9538

# %%
predictions = autoencoder.predict(np.array(x_test_logo))

# %%
n = 10
plt.figure(figsize= (25,10))
for i in range(n):
  ax = plt.subplot(3, n, i+1)
  index = np.random.randint(0, len(x_test_logo))
  plt.imshow(x_test_n[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Original Image')
  ax = plt.subplot(3, n, i+1+n)
  plt.imshow(predictions[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('AE Predictions')
  ax = plt.subplot(3, n, i+11+n)
  plt.imshow(x_test_logo[index])
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
  plt.title('Watermarked Image')
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Represeting Model as JSON String
autoencoder_json = autoencoder.to_json()
with open('LR_model.json', 'w') as json_file:
  json_file.write(autoencoder_json)
# Out:
# d:\Users\KalburgS\Anaconda3\envs\pygames\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
